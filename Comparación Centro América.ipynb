# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
Pnormal = pd.read_csv("Proyecto-normal.csv")

# %%
year = ['2000-2002',
 '2001-2003',
 '2002-2004',
 '2003-2005',
 '2004-2006',
 '2005-2007',
 '2006-2008',
 '2007-2009',
 '2008-2010',
 '2009-2011',
 '2010-1012',
 '2011-2013',
 '2012-2014',
 '2013-2015',
 '2014-2016',
 '2015-2017',
 '2016-2018',
 '2017-2019',
 '2018-2020',
 '2019-2021']

# %%
honduras = Pnormal[Pnormal.País == "Honduras"]
nicaragua = Pnormal[Pnormal.País == "Nicaragua"]
panama = Pnormal[Pnormal.País == "Panamá"]
ecuador = Pnormal[Pnormal.País == "Ecuador"]
colombia = Pnormal[Pnormal.País == "Colombia"]

# %%
col = colombia.per.to_numpy().transpose().tolist()
hn = honduras.per.to_numpy().transpose().tolist()
nica = nicaragua.per.to_numpy().transpose().tolist()
pan = panama.per.to_numpy().transpose().tolist()
ecu = ecuador.per.to_numpy().transpose().tolist()

# %%
Honduras = hn
Nicaragua = nica
Panamá = pan
plt.plot(year, Honduras)
plt.plot(year, Nicaragua)
plt.plot(year, Panamá)
plt.title("Comparación países de Centro América")
plt.xlabel("Año")
plt.ylabel("%")
plt.legend(["Honduras", "Nicaragua", "Panamá"])
plt.show()
