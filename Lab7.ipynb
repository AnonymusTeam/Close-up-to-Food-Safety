# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
Pnormal = pd.read_csv("Proyecto-normal.csv")

# %%
Pnormal
# Out:
#          País        Año   per
# 0    Honduras  2000-2002  21.9
# 1    Honduras  2001-2003  21.2
# 2    Honduras  2002-2004  21.7
# 3    Honduras  2003-2005  22.2
# 4    Honduras  2004-2006  22.3
# ..        ...        ...   ...
# 95  Nicaragua  2015-2017  18.0
# 96  Nicaragua  2016-2018  17.2
# 97  Nicaragua  2017-2019  17.4
# 98  Nicaragua  2018-2020  17.5
# 99  Nicaragua  2019-2021  18.6
#
# [100 rows x 3 columns]

# %%
# graficando

# %%
colombia = Pnormal[Pnormal.País == "Colombia"]

# %%
colombia
# Out:
#         País        Año   per
# 40  Colombia  2000-2002   8.7
# 41  Colombia  2001-2003   9.1
# 42  Colombia  2002-2004   9.8
# 43  Colombia  2003-2005  10.6
# 44  Colombia  2004-2006  11.2
# 45  Colombia  2005-2007  11.4
# 46  Colombia  2006-2008  11.0
# 47  Colombia  2007-2009  11.3
# 48  Colombia  2008-2010  12.1
# 49  Colombia  2009-2011  12.9
# 50  Colombia  2010-1012  12.3
# 51  Colombia  2011-2013  10.7
# 52  Colombia  2012-2014   8.9
# 53  Colombia  2013-2015   7.5
# 54  Colombia  2014-2016   6.5
# 55  Colombia  2015-2017   6.0
# 56  Colombia  2016-2018   5.9
# 57  Colombia  2017-2019   6.2
# 58  Colombia  2018-2020   7.2
# 59  Colombia  2019-2021   8.2

# %%
Honduras = Pnormal[Pnormal.País == "Honduras"]

# %%
Honduras
# Out:
#         País        Año   per
# 0   Honduras  2000-2002  21.9
# 1   Honduras  2001-2003  21.2
# 2   Honduras  2002-2004  21.7
# 3   Honduras  2003-2005  22.2
# 4   Honduras  2004-2006  22.3
# 5   Honduras  2005-2007  21.8
# 6   Honduras  2006-2008  21.0
# 7   Honduras  2007-2009  20.8
# 8   Honduras  2008-2010  18.3
# 9   Honduras  2009-2011  15.8
# 10  Honduras  2010-1012  13.4
# 11  Honduras  2011-2013  13.4
# 12  Honduras  2012-2014  14.2
# 13  Honduras  2013-2015  14.6
# 14  Honduras  2014-2016  14.5
# 15  Honduras  2015-2017  13.8
# 16  Honduras  2016-2018  13.2
# 17  Honduras  2017-2019  13.1
# 18  Honduras  2018-2020  13.3
# 19  Honduras  2019-2021  15.3

# %%
Ecuador = Pnormal[Pnormal.País == "Ecuador"]

# %%
Ecuador
# Out:
#        País        Año   per
# 20  Ecuador  2000-2002  21.0
# 21  Ecuador  2001-2003  22.7
# 22  Ecuador  2002-2004  22.7
# 23  Ecuador  2003-2005  22.7
# 24  Ecuador  2004-2006  22.4
# 25  Ecuador  2005-2007  22.8
# 26  Ecuador  2006-2008  22.1
# 27  Ecuador  2007-2009  21.3
# 28  Ecuador  2008-2010  16.0
# 29  Ecuador  2009-2011  12.3
# 30  Ecuador  2010-1012   8.4
# 31  Ecuador  2011-2013   8.8
# 32  Ecuador  2012-2014   8.8
# 33  Ecuador  2013-2015   8.7
# 34  Ecuador  2014-2016   9.0
# 35  Ecuador  2015-2017   9.7
# 36  Ecuador  2016-2018  10.7
# 37  Ecuador  2017-2019  11.6
# 38  Ecuador  2018-2020  13.7
# 39  Ecuador  2019-2021  15.4

# %%
Panamá = Pnormal[Pnormal.País == "Panamá"]

# %%
Panamá
# Out:
#       País        Año   per
# 60  Panamá  2000-2002  24.5
# 61  Panamá  2001-2003  20.5
# 62  Panamá  2002-2004  21.0
# 63  Panamá  2003-2005  21.3
# 64  Panamá  2004-2006  21.6
# 65  Panamá  2005-2007  18.5
# 66  Panamá  2006-2008  16.2
# 67  Panamá  2007-2009  14.1
# 68  Panamá  2008-2010  12.4
# 69  Panamá  2009-2011  10.9
# 70  Panamá  2010-1012   9.1
# 71  Panamá  2011-2013   8.4
# 72  Panamá  2012-2014   8.2
# 73  Panamá  2013-2015   8.3
# 74  Panamá  2014-2016   8.1
# 75  Panamá  2015-2017   7.8
# 76  Panamá  2016-2018   6.7
# 77  Panamá  2017-2019   6.0
# 78  Panamá  2018-2020   5.4
# 79  Panamá  2019-2021   5.8

# %%
Nicaragua = Pnormal[Pnormal.País == "Nicaragua"]

# %%
Nicaragua
# Out:
#          País        Año   per
# 80  Nicaragua  2000-2002  27.5
# 81  Nicaragua  2001-2003  25.2
# 82  Nicaragua  2002-2004  25.0
# 83  Nicaragua  2003-2005  24.0
# 84  Nicaragua  2004-2006  23.3
# 85  Nicaragua  2005-2007  22.2
# 86  Nicaragua  2006-2008  21.6
# 87  Nicaragua  2007-2009  21.2
# 88  Nicaragua  2008-2010  20.8
# 89  Nicaragua  2009-2011  20.0
# 90  Nicaragua  2010-1012  19.2
# 91  Nicaragua  2011-2013  19.0
# 92  Nicaragua  2012-2014  19.3
# 93  Nicaragua  2013-2015  19.7
# 94  Nicaragua  2014-2016  19.0
# 95  Nicaragua  2015-2017  18.0
# 96  Nicaragua  2016-2018  17.2
# 97  Nicaragua  2017-2019  17.4
# 98  Nicaragua  2018-2020  17.5
# 99  Nicaragua  2019-2021  18.6

# %%
mcol = np.mean(colombia.per)

# %%
mcol
# Out:
# 9.374999999999996

# %%
mhn = np.mean(Honduras.per)

# %%
mhn
# Out:
# 17.290000000000003

# %%
mecu = np.mean(Ecuador.per)

# %%
mecu
# Out:
# 15.540000000000001

# %%
mpn = np.mean(Panamá.per)

# %%
mpn
# Out:
# 12.74

# %%
mnic = np.mean(Nicaragua.per)

# %%
mnic
# Out:
# 20.785

# %%
ig, ax = plt.subplots()
porcentaje = [mcol, mhn, mecu, mpn, mnic]
paises = ["Colombia", "Honduras", "Ecuador", "Panamá", "Nicaragua"]
ax.bar(paises, porcentaje)

ax.set(xlabel = "País", ylabel = "Porcentaje", title = "Porcentaje de Subalimentación en 5 países de LATAM")

plt.show()
